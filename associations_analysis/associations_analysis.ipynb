# %% [markdown]
# # Regole di associazione

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/anisa_bakiu/Downloads/DM_progetto/pre-elaborazione/em_processed.csv")

# %%
df.columns.to_list()
# Out:
# ['Disaster Group',
#  'Disaster Subgroup',
#  'Disaster Type',
#  'Disaster Subtype',
#  'Country',
#  'Subregion',
#  'Total Deaths',
#  'No. Injured',
#  'No. Affected',
#  'Total Affected',
#  "Total Damage, Adjusted ('000 US$)",
#  'duration_days']

# %%
df = df.rename(columns={"Total Damage, Adjusted ('000 US$)": "Total Damage"})

# %%
quant_vars = ['Total Deaths', 'No. Injured', 'No. Affected', 
              'Total Affected', "Total Damage", 'duration_days']

for col in quant_vars:
    df[col] = pd.qcut(df[col].rank(method='first'), 
                            q=3, 
                            labels=[f'Low', f'Med', f'High'])

# %%
df_encoded = pd.get_dummies(df)

# %% [markdown]
# ## APriori

# %%
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Range di valori per support e confidence
support_levels = [0.03, 0.05, 0.07]  # min_support
confidence_levels = [0.6, 0.7, 0.8]  # min_threshold

# Lista per raccogliere risultati
regole_apriori = []

for sup in support_levels:
    freq_items = apriori(df_encoded, min_support=sup, use_colnames=True)
    
    for conf in confidence_levels:
        rules = association_rules(freq_items, metric="confidence", min_threshold=conf)
        rules['min_support'] = sup
        rules['min_confidence'] = conf
        regole_apriori.append(rules)

# Combina tutte le regole in un unico DataFrame
regole_apriori_df = pd.concat(regole_apriori, ignore_index=True)

# Ordina per lift decrescente
regole_apriori_df.sort_values(by='lift', ascending=False, inplace=True)

# %%
for i, row in regole_apriori_df.sort_values('lift', ascending=False).head(400).iterrows():
    print(f"SE {set(row['antecedents'])}  ->  ALLORA {set(row['consequents'])}")
    print(f"   support={row['support']:.2f}, confidence={row['confidence']:.2f}, lift={row['lift']:.2f}\n")
# Out:
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Group_Technological', 'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)', 'Disaster Group_Technological', 'Disaster Subgroup_Miscellaneous accident'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Type_Fire (Miscellaneous)', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Fire (Miscellaneous)'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Disaster Subtype_Fire (Miscellaneous)'}  ->  ALLORA {'Disaster Type_Fire (Miscellaneous)', 'Disaster Subgroup_Miscellaneous accident'}
#    support=0.03, confidence=1.00, lift=32.73
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subtype_Air', 'Disaster Group_Technological', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# ...
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subtype_Air', 'Disaster Group_Technological', 'Total Damage_High', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Type_Air', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Disaster Subtype_Air', 'Total Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}  ->  ALLORA {'Total Affected_High', 'Disaster Type_Air', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}  ->  ALLORA {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Damage_High', 'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Disaster Subgroup_Transport', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_High', 'Total Affected_High', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'No. Affected_High', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_High', 'Disaster Subgroup_Transport', 'Disaster Type_Air'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Total Affected_High', 'Disaster Type_Air', 'No. Affected_High'}  ->  ALLORA {'Total Damage_High', 'Disaster Subtype_Air', 'Disaster Subgroup_Transport'}
#    support=0.03, confidence=1.00, lift=31.19
#
# SE {'Disaster Subtype_Air', 'Total Affected_High', 'Total Damage_High'}  ->  ALLORA {'Disaster Type_Air', 'Disaster Subgroup_Transport', 'No. Affected_High'}
#    support=0.03, confidence=1.00, lift=31.19

# %% [markdown]
# ### Pattern orientati

# %%
cols_for_rules = (
    [c for c in df_encoded.columns if c.startswith('Disaster Type_')]
    + [c for c in df_encoded.columns if c.startswith('Total Deaths_')]
    + [c for c in df_encoded.columns if c.startswith('Total Damage_')]
    + [c for c in df_encoded.columns if c.startswith('Total Affected_')]
)

df_impatto = df_encoded[cols_for_rules]

# %%
support_levels = [0.03, 0.05, 0.07]  
confidence_levels = [0.5, 0.6, 0.7, 0.8]  

regole2 = []

for sup in support_levels:
    freq_items = apriori(df_impatto, min_support=sup, use_colnames=True)
    
    for conf in confidence_levels:
        rules = association_rules(freq_items, metric="confidence", min_threshold=conf)
        rules['min_support'] = sup
        rules['min_confidence'] = conf
        regole2.append(rules)

regole2df = pd.concat(regole2, ignore_index=True)

regole2df.sort_values(by='lift', ascending=False, inplace=True)

# %%
for i, row in regole2df.sort_values('lift', ascending=False).head(150).iterrows():
    print(f"SE {set(row['antecedents'])}  ->  ALLORA {set(row['consequents'])}")
    print(f"   support={row['support']:.2f}, confidence={row['confidence']:.2f}, lift={row['lift']:.2f}\n")
# Out:
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med', 'Total Affected_Low'}
#    support=0.04, confidence=0.64, lift=4.88
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med', 'Total Affected_Low'}
#    support=0.04, confidence=0.64, lift=4.88
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Deaths_Med'}
#    support=0.04, confidence=0.58, lift=4.74
#
# SE {'Total Damage_Low', 'Total Deaths_Med', 'Total Affected_Low'}  ->  ALLORA {'Disaster Type_Road'}
#    support=0.04, confidence=0.51, lift=4.61
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.61, lift=3.53
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.61, lift=3.53
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.61, lift=3.53
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.61, lift=3.53
#
# SE {'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low'}
#    support=0.04, confidence=0.59, lift=3.40
#
# SE {'Total Damage_Low', 'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Damage_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=3.00
#
# SE {'Total Affected_High', 'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=3.00
#
# SE {'Disaster Type_Water', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Disaster Type_Water', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=1.00, lift=2.99
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Affected_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Damage_High'}
#    support=0.13, confidence=0.95, lift=2.84
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Damage_High', 'Total Deaths_Med'}  ->  ALLORA {'Total Affected_High'}
#    support=0.13, confidence=0.94, lift=2.83
#
# SE {'Total Deaths_Med', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.04, confidence=0.92, lift=2.76
#
# SE {'Total Deaths_Med', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.04, confidence=0.92, lift=2.76
#
# SE {'Total Deaths_Med', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.04, confidence=0.92, lift=2.76
#
# SE {'Total Deaths_Med', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.04, confidence=0.92, lift=2.76
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.91, lift=2.73
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.30, confidence=0.89, lift=2.68
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.66
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.66
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Affected_High', 'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.66
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Affected_High', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.11, confidence=0.87, lift=2.60
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Damage_High', 'Total Deaths_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.11, confidence=0.86, lift=2.59
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Damage_High'}  ->  ALLORA {'Total Affected_High'}
#    support=0.06, confidence=0.85, lift=2.56
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Deaths_Low', 'Total Affected_High'}  ->  ALLORA {'Total Damage_High'}
#    support=0.06, confidence=0.84, lift=2.53
#
# SE {'Total Damage_High', 'Disaster Type_Storm'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=0.82, lift=2.45
#
# SE {'Total Damage_High', 'Disaster Type_Storm'}  ->  ALLORA {'Total Affected_High'}
#    support=0.04, confidence=0.82, lift=2.45

# %%
cols_for_rules = (
    [c for c in df_encoded.columns if c.startswith('Disaster Type_')]
    + [c for c in df_encoded.columns if c.startswith('Subregion_')]
    + [c for c in df_encoded.columns if c.startswith('Total Deaths_')]
    + [c for c in df_encoded.columns if c.startswith('Total Damage_')]
)

df_regioni = df_encoded[cols_for_rules]

support_levels = [0.03, 0.05, 0.07]  
confidence_levels = [0.5, 0.6, 0.7, 0.8]  

regole3 = []

for sup in support_levels:
    freq_items = apriori(df_regioni, min_support=sup, use_colnames=True)
    
    for conf in confidence_levels:
        rules = association_rules(freq_items, metric="confidence", min_threshold=conf)
        rules['min_support'] = sup
        rules['min_confidence'] = conf
        regole3.append(rules)

regole3df = pd.concat(regole3, ignore_index=True)

for i, row in regole3df.sort_values('lift', ascending=False).head(100).iterrows():
    print(f"SE {set(row['antecedents'])}  ->  ALLORA {set(row['consequents'])}")
    print(f"   support={row['support']:.2f}, confidence={row['confidence']:.2f}, lift={row['lift']:.2f}\n")
# Out:
# SE {'Disaster Type_Epidemic'}  ->  ALLORA {'Subregion_Sub-Saharan Africa'}
#    support=0.03, confidence=0.57, lift=3.21
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.38
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.38
#
# SE {'Disaster Type_Air'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=0.79, lift=2.38
#
# SE {'Disaster Type_Epidemic'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.04, confidence=0.78, lift=2.33
#
# SE {'Disaster Type_Epidemic'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.04, confidence=0.78, lift=2.33
#
# SE {'Disaster Type_Epidemic'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.04, confidence=0.78, lift=2.33
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=0.68, lift=2.03
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Total Damage_High'}
#    support=0.04, confidence=0.68, lift=2.03
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.07, confidence=0.67, lift=2.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.04, confidence=0.64, lift=1.93
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.04, confidence=0.64, lift=1.93
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.61, lift=1.84
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.61, lift=1.84
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.61, lift=1.84
#
# SE {'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.07, confidence=0.61, lift=1.84
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Total Deaths_Med'}
#    support=0.04, confidence=0.60, lift=1.79
#
# SE {'Total Deaths_Med', 'Disaster Type_Road'}  ->  ALLORA {'Total Damage_Low'}
#    support=0.04, confidence=0.59, lift=1.78
#
# SE {'Total Deaths_Low', 'Disaster Type_Flood'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.05, confidence=0.55, lift=1.66
#
# SE {'Disaster Type_Flood', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.05, confidence=0.55, lift=1.65
#
# SE {'Subregion_Sub-Saharan Africa', 'Total Deaths_High'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.03, confidence=0.54, lift=1.61
#
# SE {'Subregion_Northern America'}  ->  ALLORA {'Total Damage_High'}
#    support=0.03, confidence=0.51, lift=1.52
#
# SE {'Disaster Type_Flood'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.11, confidence=0.51, lift=1.52
#
# SE {'Disaster Type_Flood'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.11, confidence=0.51, lift=1.52
#
# SE {'Disaster Type_Flood'}  ->  ALLORA {'Total Damage_Med'}
#    support=0.11, confidence=0.51, lift=1.52
# /tmp/ipykernel_566041/2547254589.py:24: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   regole3df = pd.concat(regole3, ignore_index=True)

# %% [markdown]
# ## FP-Growth

# %%
from mlxtend.frequent_patterns import fpgrowth, association_rules

# Calcolo degli itemset frequenti
frequent_itemsets = fpgrowth(df_encoded, min_support=0.06, use_colnames=True)

# Generazione delle regole di associazione
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.7)

# %%
for i, row in rules.sort_values('lift', ascending=False).head(300).iterrows():
    print(f"SE {set(row['antecedents'])}  ->  ALLORA {set(row['consequents'])}")
    print(f"   support={row['support']:.2f}, confidence={row['confidence']:.2f}, lift={row['lift']:.2f}\n")
# Out:
# SE {'Disaster Subtype_Water'}  ->  ALLORA {'Disaster Type_Water', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Disaster Subtype_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water'}  ->  ALLORA {'Disaster Type_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Disaster Subtype_Water', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Disaster Subtype_Water', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Water', 'Disaster Subgroup_Transport'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Water', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water'}  ->  ALLORA {'Disaster Type_Water', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water'}  ->  ALLORA {'Disaster Type_Water', 'Disaster Subgroup_Transport'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Water', 'Disaster Subgroup_Transport'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Water', 'Disaster Group_Technological'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water', 'Disaster Subgroup_Transport', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Type_Water'}  ->  ALLORA {'Disaster Subtype_Water', 'Disaster Subgroup_Transport'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'Disaster Subtype_Water', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Type_Water'}
#    support=0.06, confidence=1.00, lift=16.10
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}  ->  ALLORA {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.02
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.02
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Affected_Low', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Disaster Group_Technological', 'No. Affected_Low', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'No. Affected_Low', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'No. Affected_Low', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'No. Affected_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Injured_Low', 'No. Affected_Low', 'Total Affected_Low'}
#    support=0.07, confidence=1.00, lift=14.01
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Affected_Low', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'No. Affected_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.01
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# ...
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Disaster Subgroup_Transport', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}  ->  ALLORA {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low', 'Disaster Group_Technological'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'Disaster Type_Road', 'No. Injured_Low'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Affected_Low', 'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road'}
#    support=0.07, confidence=0.94, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subtype_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road'}  ->  ALLORA {'Disaster Subgroup_Transport', 'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Type_Road', 'Disaster Subgroup_Transport'}  ->  ALLORA {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Total Damage_Low', 'Total Affected_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}  ->  ALLORA {'Disaster Subgroup_Transport', 'Disaster Type_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Disaster Type_Road', 'Disaster Group_Technological', 'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'Disaster Type_Road', 'Disaster Subgroup_Transport', 'Disaster Group_Technological', 'Total Damage_Low', 'Total Affected_Low'}  ->  ALLORA {'Disaster Subtype_Road', 'No. Injured_Low'}
#    support=0.07, confidence=1.00, lift=14.00
#
# SE {'No. Affected_Low', 'Total Damage_Low', 'Disaster Subgroup_Transport', 'Disaster Type_Road'}  ->  ALLORA {'No. Injured_Low', 'Disaster Subtype_Road', 'Disaster Group_Technological'}
#    support=0.07, confidence=1.00, lift=14.00
